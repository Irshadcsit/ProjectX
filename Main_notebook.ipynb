# %% [markdown]
# # Pneumonia Classification — ProjectX
#
# This notebook serves as the entry point for the project.
#
# ## Project Workflow
#
# 1. 📊 Data Analysis
# 2. 🏋️ Model Training
# 3. 📈 Evaluation & Comparison
#
# ---
#
# ## Navigation
#
# - [01_data_analysis.ipynb](https://colab.research.google.com/github/Irshadcsit/ProjectX/blob/main/01_data_analysis.ipynb)
# - [02_train.ipynb](https://colab.research.google.com/github/Irshadcsit/ProjectX/blob/main/02_train.ipynb)
# - [03_evaluate.ipynb](https://colab.research.google.com/github/Irshadcsit/ProjectX/blob/main/03_evaluate.ipynb)
#
# Author: Irshad Khan
# GitHub: https://github.com/Irshadcsit/ProjectX
